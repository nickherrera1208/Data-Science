# %%
import pandas as pd
from pandas_datareader import data as pdr
import mplfinance as fplt

# %%
ticker = "FB"
sdate = "2021-06-01"
size = 2.5
df = pdr.get_data_yahoo(ticker, start = sdate)

# %%
fplt.plot(df,type='renko',renko_params=dict(brick_size=2),style='yahoo',figsize =(18,7))
fplt.plot(df,type='line')
